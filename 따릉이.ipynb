# %% [markdown]
# <a href="https://colab.research.google.com/github/hi-rama/AI-Machine-Learning-Study/blob/main/%EB%94%B0%EB%A6%89%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload() # data.zip 업로드
# Out:
#      <input type="file" id="files-a88a09fb-fc84-4cc5-a86c-4bdff4b926d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a88a09fb-fc84-4cc5-a86c-4bdff4b926d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 따릉이.zip to 따릉이 (1).zip
# ...

# %%
! unzip 따릉이.zip
# Out:
# Archive:  따릉이.zip
# replace ╡√╕к└╠/submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use('fivethirtyeight')
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv("╡√╕к└╠/train.csv")

# %% [markdown]
# datetime에서 시간(hour)과 date를 분리해 뽑아내보세요(15분)

# %%
train['hour'].head()

# %%
train.info()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
train.groupby(['hour'])['count'].mean()

# %%
train.groupby(['hour'])['count'].mean().plot() # 시간 당 평균 count
plt.axvline(x=8,color='r') #8시 출근
plt.axvline(x=18,color='r') # 6시 퇴근
plt.text(6, 150, 'go work')
plt.text(16, 150, 'leave work')

# %%
import pandas as pd #판다스 패키지 불러오기
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor #랜덤 포레스트 불러오기
import matplotlib.pyplot as plt

# %% [markdown]
# 습기에 따라서 확인해 보기

# %%
train.groupby(['count'])['hour_bef_humidity'].mean().reset_index().sort_values(by='count')

# %%
test = pd.read_csv('╡√╕к└╠/test.csv')

# %%
test.info()

# %%
train.dropna()

# %%
from sklearn.model_selection import train_test_split

y_target = train['hour']
X_data = train.drop(['hour'],axis=1,inplace=False)

X_train, X_test, y_train, y_test = train_test_split(X_data,y_target,
                                                    test_size=0.2,random_state=11)

# %%
model = RandomForestRegressor()
model = RandomForestRegressor(criterion='mse')
model.fit(X_train, y_train)

# %% [markdown]
# hour_bef_humidity
