# %% [markdown]
# <a href="https://colab.research.google.com/github/hi-rama/AI-Machine-Learning-Study/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.utils.np_utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
from sklearn.model_selection import train_test_split

from keras import layers
from keras import models

# %%
from google.colab import files
files.upload() # data.zip 업로드
# Out:
#      <input type="file" id="files-c48c5b5c-4de2-49f1-83f7-5efa492ab275" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c48c5b5c-4de2-49f1-83f7-5efa492ab275">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample.zip to sample.zip

# %% [markdown]
# !unzip (압축 해제할 파일).zip -d (압축 해제 파일 저장 경로)

# %%
! unzip sample.zip
# Out:
# Archive:  sample.zip
#   inflating: csv 환경데이터 변수 설명.docx
#   inflating: json 데이터 변수 설명.XLSX
#   inflating: sample_data.zip

# %%
! unzip sample_data.zip
# Out:
# Archive:  sample_data.zip
#    creating: sample_data/10000/
#   inflating: sample_data/10000/10000.jpg
#   inflating: sample_data/10000/10000.json
#   inflating: sample_data/10000/10000.csv
#    creating: sample_data/10001/
#   inflating: sample_data/10001/10001.csv
#   inflating: sample_data/10001/10001.jpg
#   inflating: sample_data/10001/10001.json
#    creating: sample_data/10002/
#   inflating: sample_data/10002/10002.json
#   inflating: sample_data/10002/10002.jpg
#   inflating: sample_data/10002/10002.csv
#    creating: sample_data/10003/
#   inflating: sample_data/10003/10003.json
#   inflating: sample_data/10003/10003.csv
#   inflating: sample_data/10003/10003.jpg
#    creating: sample_data/10004/
#   inflating: sample_data/10004/10004.json
#   inflating: sample_data/10004/10004.csv
#   inflating: sample_data/10004/10004.jpg
#    creating: sample_data/10005/
#   inflating: sample_data/10005/10005.json
#   inflating: sample_data/10005/10005.csv
# ...

# %%
train = pd.read_csv("sample_data/10556/10556.csv", index_col=0)
# test = pd.read_csv("test.csv", index_col=0)
# submission = pd.read_csv("submission.csv", index_col=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-62e48cab00ed> in <module>()
#       1
# ----> 2 train.head(3)
#
# NameError: name 'train' is not defined
